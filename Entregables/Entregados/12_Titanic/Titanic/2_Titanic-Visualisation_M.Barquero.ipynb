# %% [markdown]
#    #                                                  Titanic Exercise II
#    #### Practice matplotlib & seaborn

# %% [markdown]
# ![titanic](https://userscontent2.emaze.com/images/a5f68f37-6349-4065-a1fc-921cbe7401b2/958230111417e36d6b3c67ffd7bc3494.jpeg)

# %% [markdown]
# First of all, import the needed libraries.

# %%
# visualisation libraries
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
from matplotlib.pyplot import *
import scipy.stats as stats
import seaborn as sns
sns.set_context('notebook')
sns.set_style('darkgrid')

# %% [markdown]
# 1. Read the `.csv` file you generated in **1_Titanic-Pandas** `titanic_cleaned.csv` and call the variable `titanic`.
#
# Help: If you didn't get to the point in which you should have saved the file, ask the instructor.

# %%
filename = "titanic_cleaned.csv"
titanic = pd.read_csv(filename)
titanic
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#       gender    age  sibsp  parch  ticket      fare embarked boat  \
# ...

# %% [markdown]
# 2. Using matplotlib find the appropriate visualization to show the distribution of the column `age`

# %%
#your code here
age_list = titanic['age'].dropna().to_list()

# %%
hist(age_list)
xlabel('Ages')
ylabel('Frequency')
title('Histogram for age distribution in Titanic')
# Out:
# Text(0.5, 1.0, 'Histogram for age distribution in Titanic')

# %% [markdown]
# 3. Now use seaborn to show the distribution of the column `age`.

# %%
#your code here
# titan = sns.load_dataset('titanic')
sns.histplot(age_list, bins=20)
xlabel('Ages')
ylabel('Frecuency')
# Out:
# Text(0, 0.5, 'Frecuency')

# %% [markdown]
# 4. Use subplots to plot the distribution of the Age variable with bins equal to 10, 20 and 50.
#
# Use `sns.histplot()` for that aim.

# %%
fig, axs = plt.subplots(1, 3, tight_layout=False)
axs[0].hist(age_list, bins=10)
axs[1].hist(age_list, bins=20)
axs[2].hist(age_list, bins=50)
# Out:
# (array([22., 19., 10., 11., 10., 10.,  8.,  4., 15., 25., 20., 71., 24.,
#         85., 74., 35., 61., 35., 72., 47., 25., 41., 33., 23., 39., 14.,
#         27., 10., 29., 28.,  9., 23.,  6., 14., 13.,  5.,  9.,  8., 10.,
#          9.,  3.,  2.,  0.,  2.,  3.,  0.,  1.,  1.,  0.,  1.]),
#  array([ 0.17  ,  1.7666,  3.3632,  4.9598,  6.5564,  8.153 ,  9.7496,
#         11.3462, 12.9428, 14.5394, 16.136 , 17.7326, 19.3292, 20.9258,
#         22.5224, 24.119 , 25.7156, 27.3122, 28.9088, 30.5054, 32.102 ,
#         33.6986, 35.2952, 36.8918, 38.4884, 40.085 , 41.6816, 43.2782,
#         44.8748, 46.4714, 48.068 , 49.6646, 51.2612, 52.8578, 54.4544,
#         56.051 , 57.6476, 59.2442, 60.8408, 62.4374, 64.034 , 65.6306,
#         67.2272, 68.8238, 70.4204, 72.017 , 73.6136, 75.2102, 76.8068,
#         78.4034, 80.    ]),
#  <BarContainer object of 50 artists>)

# %% [markdown]
# 5. Whether the bin size affects your plot? Why?

# %%
#your comment here
'''
the bin arg affect +s the histogram by increasing/decreasing th enumber of columns in the plot, and therefore the number of occurrencies in each column
'''
# Out:
# '\nthe bin arg affect +s the histogram by increasing/decreasing th enumber of columns in the plot, and therefore the number of occurrencies in each column\n'

# %% [markdown]
# 6. Using matplotlib find the appropriate plot to visualize the column `'gender'`

# %%
# your code here

# %%
titanic
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#       gender    age  sibsp  parch  ticket      fare embarked boat  \
# ...

# %% [markdown]
# 7. What if you also plot the column `'gender'` using the function [`countplot`](https://seaborn.pydata.org/generated/seaborn.countplot.html) from the library [`seaborn`](https://seaborn.pydata.org/)?

# %%
#your code
#gender_list = titanic['gender'].dropna().to_list()

ax = sns.countplot(x='gender', data=titanic)

# %% [markdown]
# 6. Using the function [`catplot`](https://seaborn.pydata.org/generated/seaborn.catplot.html) from the library `seaborn`, find out if the hypothesis _"Women are more likely to survive shipwrecks"_ is true or not.
#
# You should get something like this:

# %% [markdown]
# ![catplot](img/catplot.png)

# %%
#your code
ax = sns.countplot(x='gender', data=titanic, hue= 'survived')

# %%
g = sns.catplot(x="survived", col="gender", col_wrap=2, data=titanic, kind="count", height=5, aspect=.8)
(g.set_axis_labels("Survived", "Observations")
  .set_xticklabels(["No", "Yes"]))

# %%
# Women are more likely to survive in a shipwreck

# %% [markdown]
# 7. Use the appropriate plot to visualize the column `pclass`.

# %%
#your code
class_plot = sns.countplot(x='pclass', data=titanic)

# %% [markdown]
# 8. We would like to have in one single plot the summary statistics of the feature `age`. Choose the appropriate plot to show below.

# %%
#your code
sns.histplot(data=titanic, x="age", hue="pclass", multiple='dodge')
# Out:
# <AxesSubplot:xlabel='age', ylabel='Count'>

# %%
fig, axs = plt.subplots(1, 4)
axs[0] = sns.histplot(data=titanic, x="age", stat='count')
axs[1] = sns.histplot(data=titanic, x="age", stat='frequency')
axs[2] = sns.histplot(data=titanic, x="age", stat='density')
axs[3] = sns.histplot(data=titanic, x="age", stat='probability')

# %%
sns.histplot(data=titanic, x="age", stat='count')
# Out:
# <AxesSubplot:xlabel='age', ylabel='Count'>

# %%
sns.histplot(data=titanic, x="age", stat='frequency')
# Out:
# <AxesSubplot:xlabel='age', ylabel='Frequency'>

# %%
sns.histplot(data=titanic, x="age", stat='density')
# Out:
# <AxesSubplot:xlabel='age', ylabel='Density'>

# %%
sns.histplot(data=titanic, x="age", stat='probability')
# Out:
# <AxesSubplot:xlabel='age', ylabel='Probability'>

# %% [markdown]
# 9. What does the previous plot tell you about the feature Age? Comment.

# %%
# your comment here

# %% [markdown]
# 10. Now in addition to the summary statistics, we also want to visualize the distribution of `age`. Choose the appropriate plot to show below.

# %%
#your code
sns.displot(data=titanic, x='age', kind='kde')

# %%
sns.displot(data=titanic, x='age', hue='survived', kind="kde")

# %%
sns.displot(data=titanic, x='age', hue='gender', kind="kde")

# %% [markdown]
# 11. Use the appropriate plot to display the distributions of `age` in relation to `gender`.
#
# Hint: use Facetgrid to display the distribution of age for each categorical value of gender.

# %%
#your code
sns.displot(data=titanic, x='age', hue='pclass', kind="kde", palette="Set2")

# %% [markdown]
# 12. Using [`kdeplot`]("https://seaborn.pydata.org/generated/seaborn.kdeplot.html") from `seaborn` represent those who not survived distributed by age.
#
# Hint: First you should "filter" the `titanic` dataset where the column "survived" is 0, indexing the column `"age"` only.
#
# Arguments you should pass to the function:
#
#     - color = "red"
#     - label = "Not Survived"
#     - shade = True
#
# You should get something like this:

# %% [markdown]
# ![kdeplot](img/kdeplot.png)

# %%
#your code 
kplot = sns.kdeplot(data=titanic, x='age', hue='survived',fill=True)

# %% [markdown]
# 13. Using Seaborn plot the correlation matrix of various features.
#
# Hint: search how to use `heatmap`

# %%
#your code here: modification of the original titanic table to get interesting data
titanic_data = titanic.drop(columns=['name', 'sibsp','parch','ticket','embarked','boat','home.dest'])
titanic_data['passenger'] = 1

# %%
# correlation between class an survival
titanic_data_heatmap = titanic_data.drop(columns=['age', 'gender', 'fare'])
titanic_data_heatmap = titanic_data_heatmap.groupby(['pclass', 'survived']).sum()
titanic_data_heatmap = titanic_data_heatmap.reset_index().pivot('pclass', 'survived', 'passenger')
sns.heatmap(titanic_data_heatmap, linewidths=.5)
# Out:
# <AxesSubplot:xlabel='survived', ylabel='pclass'>

# %%
# correlation between fare and survival
titanic_data_heatmap = titanic_data.drop(columns=['age', 'gender', 'pclass'])
titanic_data_heatmap['fare'] = titanic_data_heatmap['fare'].apply(lambda x: x//20*20)
titanic_data_heatmap = titanic_data_heatmap.groupby(['fare', 'survived']).sum()
titanic_data_heatmap = titanic_data_heatmap.reset_index().pivot('fare', 'survived', 'passenger')
sns.heatmap(titanic_data_heatmap, linewidths=.5)
# Out:
# <AxesSubplot:xlabel='survived', ylabel='fare'>

# %%
titanic_data_heatmap = titanic_data.drop(columns=['survived', 'gender', 'pclass'])
titanic_data_heatmap['fare'] = titanic_data_heatmap['fare'].apply(lambda x: x//20*20)
titanic_data_heatmap['age'] = titanic_data_heatmap['age'].apply(lambda x: x//5*5)
titanic_data_heatmap = titanic_data_heatmap.groupby(['fare', 'age']).sum()
titanic_data_heatmap = titanic_data_heatmap.reset_index().pivot('fare', 'age', 'passenger')
sns.heatmap(titanic_data_heatmap, linewidths=.5)
# Out:
# <AxesSubplot:xlabel='age', ylabel='fare'>

# %% [markdown]
# 14. According to the previous plot, what are the most correlated feature? Comment.

# %%
#your comment here
''' 
The most correlated features are survival and fare/class.
However, it can not be unnoticed that there are a pike of observations in people of low fares, but with a certain age (between 15 and 30), 
that means that the boat had a significative working class people onboard.
'''

# %%
survived = titanic[titanic['survived'] == 1]
survived = survived.drop(columns=['name', 'sibsp','parch','ticket','embarked','boat','home.dest'])
survived['passenger'] = 1
titanic_data_heatmap = survived.drop(columns=['survived', 'gender', 'pclass'])
titanic_data_heatmap['fare'] = titanic_data_heatmap['fare'].apply(lambda x: x//20*20)
titanic_data_heatmap['age'] = titanic_data_heatmap['age'].apply(lambda x: x//5*5)
titanic_data_heatmap = titanic_data_heatmap.groupby(['fare', 'age']).sum()
titanic_data_heatmap = titanic_data_heatmap.reset_index().pivot('fare', 'age', 'passenger')
sns.heatmap(titanic_data_heatmap, linewidths=.5)
# Out:
# <AxesSubplot:xlabel='age', ylabel='fare'>

# %%
survived_female = titanic[(titanic['survived'] == 1) & (titanic['gender'] == 'female') ]
survived_female = survived_female.drop(columns=['name', 'sibsp','parch','ticket','embarked','boat','home.dest'])
survived_female['passenger'] = 1
titanic_data_heatmap = survived_female.drop(columns=['survived', 'gender', 'pclass'])
titanic_data_heatmap['fare'] = titanic_data_heatmap['fare'].apply(lambda x: x//20*20)
titanic_data_heatmap['age'] = titanic_data_heatmap['age'].apply(lambda x: x//5*5)
titanic_data_heatmap = titanic_data_heatmap.groupby(['fare', 'age']).sum()
titanic_data_heatmap = titanic_data_heatmap.reset_index().pivot('fare', 'age', 'passenger')
sns.heatmap(titanic_data_heatmap, linewidths=.5)
# Out:
# <AxesSubplot:xlabel='age', ylabel='fare'>

# %%
survived_male = titanic[(titanic['survived'] == 1) & (titanic['gender'] == 'male') ]
survived_male = survived_male.drop(columns=['name', 'sibsp','parch','ticket','embarked','boat','home.dest'])
survived_male['passenger'] = 1
titanic_data_heatmap = survived_male.drop(columns=['survived', 'gender', 'pclass'])
titanic_data_heatmap['fare'] = titanic_data_heatmap['fare'].apply(lambda x: x//20*20)
titanic_data_heatmap['age'] = titanic_data_heatmap['age'].apply(lambda x: x//5*5)
titanic_data_heatmap = titanic_data_heatmap.groupby(['fare', 'age']).sum()
titanic_data_heatmap = titanic_data_heatmap.reset_index().pivot('fare', 'age', 'passenger')
sns.heatmap(titanic_data_heatmap, linewidths=.5)
# Out:
# <AxesSubplot:xlabel='age', ylabel='fare'>
